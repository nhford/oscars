# %%
import pandas as pd

# %%
df = pd.read_csv('s.csv')
df
# Out:
#      id                                   title  watched  release  rating  \
# 0   ABM                        A Beautiful Mind     2024     2001       6
# 1   AMH                         American Hustle     2024     2013       6
# 2   APS                         American Psycho     2024     2000       5
# 3   ARR                                 Arrival     2024     2016       7
# 4   BTM                              The Batman     2024     2022       5
# ..  ...                                     ...      ...      ...     ...
# 76  TG1                                 Top Gun     2025     1986       5
# 77  TG2                       Top Gun: Maverick     2025     2022       9
# 78  VRT                                 Vertigo     2025     1958       7
# 79  KO3  Wake Up Dead Man: A Knives Out Mystery     2025     2025       6
# 80  ZO2                              Zootopia 2     2025     2025       6
#
#    grade actor actorName actorId supporting           suppName suppId  \
# ...

# %%
df.to_json('src/app/assets/movies.json',orient='records')
